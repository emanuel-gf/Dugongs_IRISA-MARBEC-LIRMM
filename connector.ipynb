# %% [markdown]
# # Connector
#
# ## Fiftyone
#
# This is the connector to manipulate the dataset class of fiftyone.

# %%
import fiftyone as fo

## list all dataset
print(fo.list_datasets())

# Close any zombie sessions that might be hanging
fo.close_app()
# Out:
# ['Domain-Shift', 'New Caledonia']

# %%
# load dataset
dataset = fo.load_dataset("Domain-Shift")

## launch session
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=21a42846-522d-4ee7-8ded-8d6a4f5d964a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(fo.config)
# Out:
# {
#     "allow_legacy_orchestrators": false,
#     "batcher_static_size": 100,
#     "batcher_target_latency": 0.2,
#     "batcher_target_size_bytes": 1048576,
#     "database_admin": true,
#     "database_compressor": null,
#     "database_dir": "/home/camarada/.fiftyone/var/lib/mongo",
#     "database_name": "fiftyone",
#     "database_uri": "mongodb://localhost:27017",
#     "database_validation": true,
#     "dataset_zoo_dir": "/home/camarada/fiftyone",
#     "dataset_zoo_manifest_paths": null,
#     "default_app_address": "localhost",
#     "default_app_port": 5151,
#     "default_batch_size": null,
#     "default_batcher": "latency",
#     "default_dataset_dir": "/home/camarada/fiftyone",
#     "default_image_ext": ".jpg",
#     "default_ml_backend": null,
#     "default_parallelization_method": null,
#     "default_process_pool_workers": null,
#     "default_sequence_idx": "%06d",
#     "default_thread_pool_workers": null,
#     "default_video_ext": ".mp4",
#     "delegated_operation_monitor_interval": 60,
#     "do_not_track": false,
#     "execution_cache_enabled": true,
#     "logging_debug_targets": "",
#     "logging_destination": "stdout",
#     "logging_format": "text",
#     "logging_level": "INFO",
#     "max_process_pool_workers": null,
#     "max_thread_pool_workers": null,
#     "model_zoo_dir": "/home/camarada/fiftyone/__models__",
#     "model_zoo_manifest_paths": null,
#     "module_path": null,
#     "operator_timeout": 600,
#     "plugins_cache_enabled": false,
#     "plugins_dir": "/home/camarada/fiftyone/__plugins__",
#     "requirement_error_level": 0,
#     "show_progress_bars": true,
#     "singleton_cache": true,
#     "timezone": null
# }
