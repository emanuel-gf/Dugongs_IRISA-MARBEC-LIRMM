# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuel-gf/Dugongs_IRISA-MARBEC-LIRMM/blob/notebook/docs/source/tutorials/gemini_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Gemini Vision in FiftyOne

# %% [markdown]
# ## Setup

# %% [markdown]
# To get started, you need to install [FiftyOne](https://docs.voxel51.com/getting_started/install.html) and the Gemini Vision Plugin:

# %%
# !pip install fiftyone
# Out:
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.4.1-py3-none-manylinux1_x86_64.whl size=50655255 sha256=7f23a6bc3a959ccbc9403f2ce8f20f2ab46964d57a1cd78760126ed0c4d6397c
#   Stored in directory: /root/.cache/pip/wheels/fc/06/06/0eb7530b99c4934bf36390769cff3f0052fd04f50f390d5c8b
# Successfully built fiftyone-db
# Installing collected packages: texttable, sortedcontainers, pprintpp, xmltodict, wsproto, sseclient-py, retrying, rarfile, pyppmd, pydash, pybcj, priority, plotly, multivolumefile, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, exceptiongroup, dnspython, Deprecated, dacite, cross-web, bcrypt, backports.zstd, async_lru, argcomplete, strawberry-graphql, pynacl, pymongo, py7zr, hypercorn, botocore, universal-analytics-python3, sse-starlette, s3transfer, paramiko, motor, mongoengine, fiftyone-brain, voxel51-eta, boto3, fiftyone
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: sse-starlette
#     Found existing installation: sse-starlette 3.2.0
#     Uninstalling sse-starlette-3.2.0:
#       Successfully uninstalled sse-starlette-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mcp 1.26.0 requires sse-starlette>=1.6.1, but you have sse-starlette 0.10.3 which is incompatible.
# Successfully installed Deprecated-1.3.1 argcomplete-3.6.3 async_lru-2.2.0 backports.zstd-1.3.0 bcrypt-5.0.0 boto3-1.42.58 botocore-1.42.58 cross-web-0.4.1 dacite-1.9.2 dnspython-2.8.0 exceptiongroup-1.3.1 fiftyone-1.13.2 fiftyone-brain-0.21.5 fiftyone-db-1.4.1 ftfy-6.3.1 graphql-core-3.2.7 hypercorn-0.18.0 inflate64-1.0.4 jmespath-1.1.0 jsonlines-4.0.0 mongoengine-0.29.1 motor-3.6.1 multivolumefile-0.2.3 paramiko-3.5.1 plotly-6.5.2 pprintpp-0.4.0 priority-2.0.0 py7zr-1.1.0 pybcj-1.0.7 pydash-8.0.6 pymongo-4.9.2 pynacl-1.6.2 pyppmd-1.3.1 rarfile-4.2 retrying-1.4.2 s3transfer-0.16.0 sortedcontainers-2.4.0 sse-starlette-0.10.3 sseclient-py-1.9.0 strawberry-graphql-0.291.3 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.15.3 wsproto-1.3.2 xmltodict-1.0.4

# %%
# !fiftyone plugins download https://github.com/AdonaiVera/gemini-vision-plugin

# %% [markdown]
# ### Configure Gemini API Access

# %% [markdown]
# To use the Gemini Vision Plugin, you'll need a Google Cloud account with the Gemini API enabled.
#
# **Important**: The Gemini API requires billing to be enabled on your Google Cloud account. You can get started at [Google AI Studio](https://aistudio.google.com/app/apikey).
#
# Once you have your API key, set it as an environment variable:

# %%
import os

# Set your Gemini API key
os.environ["GEMINI_API_KEY"] = "YOUR_GEMINI_API_KEY"

# %% [markdown]
# Now import FiftyOne and related modules:

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.brain as fob
from fiftyone import ViewField as F
import fiftyone.operators as foo
from fiftyone.utils.huggingface import load_from_hub

## drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# change the name of the path to your Drive path.

# %%
# !cp /content/drive/MyDrive/Thesis_MASTER_CDE/DATA/RAW_DATASET/DATASET_og.zip .

# %%
# !unzip /content/DATASET_og.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_553.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_552.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_551.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_550.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_55.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_549.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_548.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_547.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_546.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_544.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_543.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_542.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_54.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_53.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_52.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_51.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_50.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_5.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_49.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_480.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_48.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_472.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_47.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_469.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_464.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_46.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_456.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_455.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_454.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_453.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_45.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_442.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_440.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_44.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_437.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_436.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_435.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_432.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_431.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_43.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_423.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_422.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_42.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_419.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_418.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_414.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_413.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_412.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_411.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_410.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_41.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_407.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_406.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_405.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_404.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_403.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_402.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_401.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_400.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_40.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_4.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_399.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_398.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_397.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_396.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_395.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_394.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_393.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_392.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_391.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_390.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_39.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_389.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_388.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_387.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_386.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_385.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_384.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_383.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_382.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_381.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_380.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_38.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_379.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_378.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_377.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_376.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_375.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_374.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_373.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_372.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_371.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_370.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_37.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_369.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_368.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_367.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_36.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_358.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_357.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_355.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_354.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_353.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_352.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_351.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_350.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_35.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_349.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_348.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_347.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_346.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_345.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_344.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_343.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_342.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_341.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_340.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_34.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_339.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_338.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_337.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_336.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_335.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_334.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_333.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_332.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_331.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_330.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_33.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_329.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_328.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_327.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_326.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_325.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_324.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_323.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_322.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_321.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_320.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_32.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_319.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_318.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_317.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_316.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_315.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_314.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_313.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_312.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_311.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_310.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_31.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_309.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_308.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_307.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_306.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_305.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_304.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_303.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_302.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_301.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_300.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_30.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_3.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_298.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_297.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_299.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_296.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_295.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_294.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_293.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_292.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_291.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_290.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_29.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_289.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_288.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_287.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_286.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_285.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_284.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_283.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_282.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_281.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_280.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_28.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_279.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_278.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_277.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_276.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_275.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_27.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_26.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_25.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_249.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_246.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_242.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_24.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_23.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_228.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_22.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_214.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_213.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_211.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_210.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_21.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_209.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_208.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_207.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_206.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_205.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_204.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_203.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_200.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_20.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_2.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_19.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_18.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_175.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_174.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_173.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_170.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_17.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_169.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_168.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_16.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_15.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_14.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_135.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_131.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_13.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_129.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_128.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_127.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_126.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_125.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_124.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_123.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_122.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_121.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_120.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_12.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_119.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_118.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_117.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_116.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_115.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_114.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_113.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_112.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_111.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_110.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_11.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_109.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_108.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_107.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_106.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_105.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_104.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_103.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_102.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_101.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_100.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_10.txt
#   inflating: DATASET/WP/UM/UM_M5/labels_yolo/MAN_P4_UM_M5_F2_GSP_DJI_0221-657c57e81272f_1.txt
#    creating: DATASET/WP/UM/UM_M6/
#    creating: DATASET/WP/UM/UM_M6/images/
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_98.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_99.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_97.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_96.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_95.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_94.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_93.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_92.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_91.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_90.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_89.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_88.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_87.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_86.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_85.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_84.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_83.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_82.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_81.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_80.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_79.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_78.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_77.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_76.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_75.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_74.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_73.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_72.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_71.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_70.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_69.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_68.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_67.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_66.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_65.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_64.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_63.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_62.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_61.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_60.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_59.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_58.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_57.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_56.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_55.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_54.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_53.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_52.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_51.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_50.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_49.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_48.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_47.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_46.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_45.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_44.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_43.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_42.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_41.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_40.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_39.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_38.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_37.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_36.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_35.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_34.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_33.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_32.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_31.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_30.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_29.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_281.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_280.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_28.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_279.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_278.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_277.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_276.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_275.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_274.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_273.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_272.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_271.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_270.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_27.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_268.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_269.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_267.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_266.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_265.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_264.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_263.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_262.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_261.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_260.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_26.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_259.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_258.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_257.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_256.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_255.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_254.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_253.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_252.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_251.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_250.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_25.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_249.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_248.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_247.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_246.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_245.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_244.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_243.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_242.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_241.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_240.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_24.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_239.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_238.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_237.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_236.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_235.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_234.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_233.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_232.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_231.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_230.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_23.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_229.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_228.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_227.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_226.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_224.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_225.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_222.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_223.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_221.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_220.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_219.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_22.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_218.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_217.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_216.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_215.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_214.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_213.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_212.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_211.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_210.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_21.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_209.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_208.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_207.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_206.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_205.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_204.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_203.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_201.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_202.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_20.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_200.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_199.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_198.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_197.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_196.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_195.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_194.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_193.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_192.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_191.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_190.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_19.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_189.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_188.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_187.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_186.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_185.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_184.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_183.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_182.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_181.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_180.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_18.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_179.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_178.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_177.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_176.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_175.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_174.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_173.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_172.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_171.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_170.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_17.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_169.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_168.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_167.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_166.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_165.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_164.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_163.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_162.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_161.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_160.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_16.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_159.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_158.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_157.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_156.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_155.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_154.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_153.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_152.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_151.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_150.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_15.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_149.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_148.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_147.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_146.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_145.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_144.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_143.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_142.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_141.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_140.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_14.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_139.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_138.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_137.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_136.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_135.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_134.jpeg
#   inflating: DATASET/WP/UM/UM_M6/images/MAN_P4_UM_M6_F2_GSP_DJI_0224-658070ac304b8_133.jpeg
# ...
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_27.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_26.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_25.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_24.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_23.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_22.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_21.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_20.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_2.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_19.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_18.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_17.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_16.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_15.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_14.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_13.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_12.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_11.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_10.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0309-64ec46505487e_1.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_9.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_8.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_7.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_63.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_62.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_61.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_60.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_6.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_59.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_58.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_57.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_56.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_55.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_54.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_53.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_52.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_51.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_50.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_5.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_49.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_48.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_47.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_46.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_45.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_44.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_43.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_42.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_41.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_40.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_4.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_39.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_38.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_37.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_36.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_35.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_34.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_33.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_32.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_31.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_30.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_3.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_29.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_28.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_27.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_26.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_25.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_24.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_23.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_22.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_21.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_20.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_2.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_19.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_18.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_17.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_16.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_15.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_14.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_13.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_12.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_11.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_10.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0299-64ec46dd2c86c_1.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_9.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_8.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_7.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_63.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_62.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_61.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_60.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_6.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_59.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_57.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_58.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_55.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_56.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_54.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_53.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_52.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_51.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_50.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_5.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_49.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_48.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_47.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_46.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_45.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_44.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_43.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_42.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_41.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_40.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_4.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_39.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_38.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_37.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_36.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_35.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_34.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_33.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_32.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_31.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_30.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_3.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_29.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_28.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_27.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_26.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_25.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_24.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_23.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_22.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_21.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_20.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_2.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_19.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_18.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_17.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_16.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_15.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_14.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_13.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_12.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_11.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_10.txt
#   inflating: DATASET/WP/GAM/GAM_M1/labels_yolo/MAN_P4_GAM_M1_F2_GSP_DJI_0295-64ec4698f3e31_1.txt
#    creating: DATASET/WP/MANTASANDY/
#    creating: DATASET/WP/MANTASANDY/MANTASANDY_M5/
#    creating: DATASET/WP/MANTASANDY/MANTASANDY_M5/images/
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/images/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_5.jpeg
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/images/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_4.jpeg
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/images/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_18.jpeg
#    creating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels/
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_5.txt
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_18.txt
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_4.txt
#    creating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels_yolo/
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels_yolo/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_5.txt
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels_yolo/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_4.txt
#   inflating: DATASET/WP/MANTASANDY/MANTASANDY_M5/labels_yolo/FPLAN_P4P_MANTASANDY_M5_GSPzip-6495ab5e293b6_18.txt
#   inflating: DATASET/WP/dugong_environmental_variables_WP.xlsx
#   inflating: DATASET/DOCUMENTATION DATASET.docx

# %% [markdown]
# ## import dataset
#
# Import copy raw dataset to this instance and unzip.

# %%
dataset = foz.load_zoo_dataset("quickstart")
session = fo.launch_app(dataset, auto=False)

# %% [markdown]
# ![question_answer_gemini](https://cdn.voxel51.com/tutorial_gemini_vision/question_answer_gemini.webp)

# %% [markdown]
# ### 2. OCR: Extracting Text and Adding It to Your Dataset
#
# Next, we move into **OCR (Optical Character Recognition)**.
#
# Here, Gemini Vision is used to dynamically extract structured information from documents such as invoices, receipts, or forms. For example:
#
# * Invoice numbers
# * Dates
# * Total amounts
# * Vendor names
#
# We then map this extracted information back into the dataset using **bounding boxes**, so the detected text becomes a first-class citizen in FiftyOne—searchable, filterable, and visualizable.
#
# This enables workflows like:
#
# * Auditing documents
# * Validating annotations
# * Building downstream analytics pipelines
#
# In this example, we load a receipts dataset directly from Hugging Face (`Voxel51/consolidated_receipt_dataset`) to show how quickly you can enrich real-world document data with OCR annotations inside FiftyOne.
#
# You can access more than 100 datasets already available in FiftyOne format—explore the full dataset ecosystem here:
# [https://docs.voxel51.com/dataset_zoo/index.html](https://docs.voxel51.com/dataset_zoo/index.html)

# %%
# Load the dataset
dataset = load_from_hub("Voxel51/consolidated_receipt_dataset")
session = fo.launch_app(dataset, auto=False)

# %% [markdown]
# ![ocr_gemini](https://cdn.voxel51.com/tutorial_gemini_vision/ocr_gemini.webp)

# %% [markdown]
# ### 3. Spatial Understanding with Keypoints and References
#
# In this section, we explore **spatial understanding**.
#
# The idea here is not just to recognize *what* is in an image, but *where* things are and how they relate to each other. Gemini Vision can point to specific regions or objects, and we can visualize these results using **FiftyOne keypoints and spatial annotations**.
#
# Examples include:
#
# * Pointing to specific components in an image
# * Highlighting regions of interest
# * Visualizing relationships between objects
#
# For this example, we use the [ALOHA Pen Uncap dataset](https://docs.voxel51.com/dataset_zoo/datasets_hf/aloha_pen_uncap.html) from Hugging Face, which contains real-world robot manipulation demonstrations captured from an egocentric perspective. The dataset is designed for studying fine-grained manipulation, action understanding, and spatial reasoning in robotics:

# %%
dataset = load_from_hub("Voxel51/aloha_pen_uncap", max_samples=100)
session = fo.launch_app(dataset, auto=False)

# %% [markdown]
# ![pointing](https://cdn.voxel51.com/tutorial_gemini_vision/pointing.webp)

# %% [markdown]
# ### 4. Video Understanding: Events, Timing, and Context
#
# Finally, we extend these ideas to **video understanding**.
#
# Instead of analyzing a single image, we process full videos to:
#
# * Understand what is happening over time
# * Detect key events
# * Extract timestamps and temporal segments
# * Answer questions about sequences and actions
#
# This is particularly useful for applications like surveillance, sports analysis, robotics, or long-form video datasets.

# %%
dataset = foz.load_zoo_dataset("quickstart-video")
session = fo.launch_app(dataset, auto=False)

# %% [markdown]
# ![video](https://cdn.voxel51.com/tutorial_gemini_vision/video.webp)

# %% [markdown]
# ### Why This Matters
#
# By combining **Gemini Vision’s multimodal reasoning** with **FiftyOne’s dataset management and visualization**, you can:
#
# * Explore datasets faster
# * Add rich semantic metadata
# * Debug data issues visually
# * Build more interpretable AI systems
#
# Next, let’s put this into practice.
# We’ll walk through a hands-on driving example, starting with dataset exploration and then using Gemini to analyze, enrich, and improve the quality of the dataset, step by step.

# %% [markdown]
# ## Load the KITTI Dataset

# %% [markdown]
# For this tutorial, we'll use the [KITTI Dataset](https://www.cvlibs.net/datasets/kitti/), a large-scale diverse driving dataset containing 7,481 annotated images, and the test split contains 7,518 unlabeled images, across various weather conditions, times of day, and scenes.
#
# KITTI is perfect for demonstrating Gemini Vision's capabilities because:
# * It contains diverse real-world scenarios
# * It has complex multi-object scenes
# * It's used for autonomous driving research, where dataset quality is critical
# * It may contain annotation biases and gaps that we can identify and address
#
# Downloading the dataset for the first time can take around 30 minutes, and for this tutorial, we'll use a subset of the training split.

# %%
dataset = foz.load_zoo_dataset(
    "kitti",
    dataset_name = "gemini-vision-tutorial",
    split="train",
    persistent=True,
    max_samples=100,
)

# %% [markdown]
# Let's visualize the dataset in the FiftyOne App:

# %%
session = fo.launch_app(dataset)

# %% [markdown]
# ![intial_notebook](https://cdn.voxel51.com/tutorial_gemini_vision/intial_notebook.webp)

# %% [markdown]
# ## Analyzing Dataset Quality with FiftyOne Brain

# %% [markdown]
# Before we start using Gemini Vision, let's analyze our dataset to understand its characteristics and identify potential issues. FiftyOne Brain provides powerful capabilities for dataset analysis.

# %% [markdown]
# ### Identifying Class Imbalance and Bias

# %% [markdown]
# First, let’s examine the distribution of object classes in our dataset to identify any biases or underrepresented categories. You can also explore these insights with the [Dashboard plugin](https://docs.voxel51.com/plugins/plugins_ecosystem/dashboard.html), which lets you build custom dashboards to visualize key statistics about your dataset.

# %%
# Count the distribution of object classes in detections
class_counts = dataset.count_values("ground_truth.detections.label")

# Display class distribution
print("Object Class Distribution:")
print("=" * 50)
for cls, count in sorted(class_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{cls}: {count}")
# Out:
# Object Class Distribution:
# ==================================================
# Car: 28742
# DontCare: 11295
# Pedestrian: 4487
# Van: 2914
# Cyclist: 1627
# Truck: 1094
# Misc: 973
# Tram: 511
# Person_sitting: 222

# %% [markdown]
# ### Computing Dataset Uniqueness

# %% [markdown]
# Next, let's use FiftyOne Brain to identify unique and potentially redundant samples in our dataset:

# %%
# Compute uniqueness scores
fob.compute_uniqueness(dataset)

# Sort by uniqueness to see most and least unique samples
unique_view = dataset.sort_by("uniqueness", reverse=True)

print(f"Most unique samples (uniqueness > 0.9): {len(dataset.match(F('uniqueness') > 0.9))}")
print(f"Potentially redundant samples (uniqueness < 0.3): {len(dataset.match(F('uniqueness') < 0.3))}")

# %% [markdown]
# ![compute_uniqueness](https://cdn.voxel51.com/tutorial_gemini_vision/compute_uniqueness.webp)

# %% [markdown]
# ### Detecting Near-Duplicate Images

# %% [markdown]
# Duplicate or near-duplicate images can inflate evaluation metrics and waste training time. Let's find them:

# %%
# Detect near-duplicate images
results = fob.compute_similarity(
    dataset,
    model="clip-vit-base32-torch",
    brain_key="img_sim"
)

# Find potential duplicates
dup_view = dataset.sort_by("uniqueness").limit(20)
session.view = dup_view

# %% [markdown]
# ### Visualizing Dataset Embeddings

# %% [markdown]
# Let's compute embeddings and visualize the dataset structure to identify clusters and potential gaps:

# %%
# !pip install umap-learn

# %%
# Compute visualization with embeddings
results = fob.compute_visualization(
    dataset,
    model="clip-vit-base32-torch",
    brain_key="img_viz",
    method="umap"
)

# Launch app to view the embeddings visualization
session = fo.launch_app(dataset)

# %% [markdown]
# ![umap](https://cdn.voxel51.com/tutorial_gemini_vision/umap.webp)

# %% [markdown]
# The embeddings plot in the FiftyOne App reveals clustering patterns in the data. Isolated samples or sparse regions may indicate underrepresented scenarios that need more data.

# %% [markdown]
# ## Using Gemini Vision for Image Understanding

# %% [markdown]
# Now let's use the Gemini Vision Plugin to query and understand images in our dataset. The plugin provides several operators that can be accessed through the FiftyOne App or programmatically.
#
# ### Querying Images with Natural Language

# %% [markdown]
# Let's select a few samples and use Gemini to analyze them. First, we'll select some samples with specific objects:

# %%
# Select samples with cars
car_view = dataset.filter_labels("ground_truth", F("label") == "Car").take(5)

# View in the app
session.view = car_view

# %% [markdown]
# ![query_images](https://cdn.voxel51.com/tutorial_gemini_vision/query_images.webp)|

# %% [markdown]
# Now, you can use the Gemini Vision Plugin operators from the FiftyOne App:
#
# 1. Select one or more samples in the App
# 2. Press the backtick key (\`) to open the operator browser
# 3. Search for "query_gemini_vision" or "Query Gemini Vision"
# 4. Enter your query, for example:
#    - "Describe the weather and lighting conditions in this image"
#    - "What time of day does this appear to be?"
#    - "Are there any pedestrians or cyclists visible?"
#    - "Describe potential safety hazards in this driving scene"
#
# The plugin will use Gemini Vision to analyze the image and return a text response, which you can save to a custom field in your dataset.

# %% [markdown]
# ### Identifying Missing Annotations

# %% [markdown]
# One powerful use case for Gemini Vision is identifying objects that may be missing from annotations. Let's use it to audit our annotations:

# %%
# Select a sample to analyze
sample = dataset.first()

# Get the list of currently annotated classes
annotated_classes = [det.label for det in sample.ground_truth.detections]

print(f"Currently annotated classes: {set(annotated_classes)}")
print("\nUse the Gemini Vision Query operator in the App to ask:")
print("'List all objects visible in this image, especially those that might be relevant for autonomous driving.'")
print("\nCompare Gemini's response with the annotations to find missing objects.")

view = dataset.select([sample.id])
session = fo.launch_app(view)

# %% [markdown]
# ![missing_annotations](https://cdn.voxel51.com/tutorial_gemini_vision/missing_annotations.webp)

# %% [markdown]
# ### Analyzing Difficult or Ambiguous Cases

# %% [markdown]
# Let's identify samples with many objects that might be challenging to annotate:

# %%
# Find samples with many objects
dataset.compute_metadata()

# Count detections per sample
for sample in dataset:
    if sample.ground_truth:
        sample["num_objects"] = len(sample.ground_truth.detections)
    else:
        sample["num_objects"] = 0
    sample.save()

# View samples with the most objects
complex_view = dataset.sort_by("num_objects", reverse=True).limit(10)
session.view = complex_view

print("These complex scenes are good candidates for Gemini Vision analysis to:")
print("- Verify annotation completeness")
print("- Identify occlusions and difficult objects")
print("- Understand scene context and relationships between objects")

# %% [markdown]
# ![complex_scene](https://cdn.voxel51.com/tutorial_gemini_vision/complex_scene.webp)

# %% [markdown]
# ## Detecting Missing Classes and Coverage Gaps

# %% [markdown]
# Based on our class distribution analysis, we may have identified underrepresented object classes. Let's systematically find which classes are missing or underrepresented:

# %%
# Get all classes present in the dataset
class_counts = dataset.count_values("ground_truth.detections.label")
all_classes = sorted(class_counts.keys())

# Define a threshold for rare classes
threshold = 5  # Consider classes with fewer than 5 instances as rare

# Identify rare classes
rare_classes = []
for cls, count in class_counts.items():
    if count < threshold:
        rare_classes.append((cls, count))

print(f"Total classes in dataset: {len(all_classes)}")
print(f"\nRare classes (< {threshold} instances):")
for cls, count in sorted(rare_classes, key=lambda x: x[1]):
    print(f"  - {cls}: {count} instances")

print("\nMost common classes:")
for cls, count in sorted(class_counts.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"  - {cls}: {count} instances")
# Out:
# Total classes in dataset: 9
#
# Rare classes (< 5 instances):
#
# Most common classes:
#   - Car: 28742 instances
#   - DontCare: 11295 instances
#   - Pedestrian: 4487 instances
#   - Van: 2914 instances
#   - Cyclist: 1627 instances

# %% [markdown]
# ### Identifying Scenario Coverage Gaps

# %% [markdown]
# Beyond object classes, we should also consider scenario diversity. Let's use Gemini Vision to categorize our images by scenario characteristics:

# %%
# Sample a subset for scenario analysis
analysis_view = dataset.take(50)

print("Use the Gemini Vision Query operator to categorize these samples by:")
print("\n1. Weather conditions:")
print("   Query: 'What are the weather conditions? Classify as: clear, rainy, foggy, snowy, or cloudy.'")
print("\n2. Time of day:")
print("   Query: 'What time of day is this? Classify as: dawn, day, dusk, or night.'")
print("\n3. Scene type:")
print("   Query: 'What type of driving environment is this? Classify as: highway, urban, residential, or rural.'")
print("\nSave responses to custom fields like 'gemini_weather', 'gemini_time', 'gemini_scene'")
print("Then use FiftyOne's count_values() to identify underrepresented scenarios.")
# Out:
# Use the Gemini Vision Query operator to categorize these samples by:
#
# 1. Weather conditions:
#    Query: 'What are the weather conditions? Classify as: clear, rainy, foggy, snowy, or cloudy.'
#
# 2. Time of day:
#    Query: 'What time of day is this? Classify as: dawn, day, dusk, or night.'
#
# 3. Scene type:
#    Query: 'What type of driving environment is this? Classify as: highway, urban, residential, or rural.'
#
# Save responses to custom fields like 'gemini_weather', 'gemini_time', 'gemini_scene'
# Then use FiftyOne's count_values() to identify underrepresented scenarios.

# %% [markdown]
# ## Addressing Dataset Gaps with Image Generation

# %% [markdown]
# Now that we've identified missing classes and underrepresented scenarios, let's use Gemini's text-to-image generation capabilities to create synthetic training data.

# %% [markdown]
# ### Generating Images for Missing Classes

# %% [markdown]
# The Gemini Vision Plugin includes a text-to-image generation operator. You can use it from the FiftyOne App:
#
# 1. Open the operator browser (backtick key)
# 2. Search for "generate_image" or "Generate Image"
# 3. Enter prompts for missing or rare classes:
#
# **Example prompts for autonomous driving scenarios:**

# %%
# Example: Define prompts for missing scenarios programmatically
generation_prompts = {
    "fire_hydrant": "A city street scene with a fire hydrant in the foreground, cars parked on the side, shot from a dashboard camera perspective",
    "motorcycle": "A motorcyclist riding on a highway during sunset, viewed from a car's perspective",
    "cyclist_rain": "A residential street with a cyclist and a stop sign, rainy weather, dashboard camera view",
    "night_traffic": "A busy urban intersection at night with traffic lights, pedestrians crossing, and various vehicles",
    "foggy_highway": "A foggy morning highway scene with trucks and cars, limited visibility"
}

print("Use these prompts with the Gemini Generate Image operator:")
for name, prompt in generation_prompts.items():
    print(f"\n{name}:")
    print(f"  {prompt}")
# Out:
# Use these prompts with the Gemini Generate Image operator:
#
# fire_hydrant:
#   A city street scene with a fire hydrant in the foreground, cars parked on the side, shot from a dashboard camera perspective
#
# motorcycle:
#   A motorcyclist riding on a highway during sunset, viewed from a car's perspective
#
# cyclist_rain:
#   A residential street with a cyclist and a stop sign, rainy weather, dashboard camera view
#
# night_traffic:
#   A busy urban intersection at night with traffic lights, pedestrians crossing, and various vehicles
#
# foggy_highway:
#   A foggy morning highway scene with trucks and cars, limited visibility

# %% [markdown]
# ![generate_images](https://cdn.voxel51.com/tutorial_gemini_vision/generate_images.webp)

# %% [markdown]
# ## Editing Images to Augment Dataset Diversity

# %% [markdown]
# In addition to generating new images, Gemini Vision can edit existing images based on natural language instructions. This is useful for creating variations and augmenting dataset diversity.

# %% [markdown]
# ### Using the Image Editing Operator

# %% [markdown]
# To edit images with Gemini Vision:
#
# 1. Select a single sample in the FiftyOne App
# 2. Open the operator browser (backtick key)
# 3. Search for "edit_image" or "Edit Image"
# 4. Enter editing instructions
#
# **Example editing prompts:**
# The edited image will be saved with the original prompt preserved in metadata.

# %%
# Select samples with clear weather for editing
clear_weather_view = dataset.take(10)
session.view = clear_weather_view

print("Selected samples for editing. Use the Edit Image operator with prompts like:")
print("  - 'Change the weather to rainy, add rain and wet roads'")
print("  - 'Make it nighttime with street lights illuminated'")
print("  - 'Add fog to reduce visibility'")
print("\nThis creates weather and lighting variations to improve model robustness.")

# %% [markdown]
# ![editing_images](https://cdn.voxel51.com/tutorial_gemini_vision/editing_images.webp)

# %% [markdown]
# ## Transferring Styles Between Images

# %% [markdown]
# Gemini Vision can combine multiple images to create new scenes or transfer styles. This is useful for:
# * Transferring weather conditions from one image to another
# * Combining objects from different scenes
# * Creating composite training examples

# %% [markdown]
# ### Using Multi-Image Composition

# %% [markdown]
# To use multi-image composition:
#
# 1. Select 2-3 samples in the FiftyOne App
# 2. Open the operator browser
# 3. Search for "compose_images" or "Multi-Image Composition"
# 4. Enter composition instructions
#
# **Example composition prompts:**

# %%
# This example shows the concept - actual execution is done through the App
print("Multi-Image Composition Workflow:")
print("\n1. Find an image with desired weather/lighting conditions")
print("2. Find an image with desired scene/object composition")
print("3. Select both images")
print("4. Use Multi-Image Composition operator to combine them")
print("\nExample: Transfer nighttime lighting to a daytime scene,")
print("creating a diverse set of lighting conditions for training.")
# Out:
# Multi-Image Composition Workflow:
#
# 1. Find an image with desired weather/lighting conditions
# 2. Find an image with desired scene/object composition
# 3. Select both images
# 4. Use Multi-Image Composition operator to combine them
#
# Example: Transfer nighttime lighting to a daytime scene,
# creating a diverse set of lighting conditions for training.

# %% [markdown]
# ![multi_image_composition](https://cdn.voxel51.com/tutorial_gemini_vision/multi_image_composition.webp)

# %% [markdown]
# ## Video Understanding with Gemini Vision

# %% [markdown]
# Gemini Vision also supports video understanding, allowing you to analyze temporal sequences and extract insights from video data. This is particularly relevant for autonomous driving where temporal context matters.

# %% [markdown]
# ### Loading Video Data

# %% [markdown]
# Let's load a video dataset to demonstrate Gemini's video understanding capabilities:

# %%
# Load the quickstart-video dataset
video_dataset = foz.load_zoo_dataset(
    "quickstart-video",
    max_samples=5
)

video_dataset.name = "gemini-vision-video"
video_dataset.persistent = True

# Launch app to view videos
session = fo.launch_app(video_dataset)

# %% [markdown]
# ### Querying Video Content

# %% [markdown]
# The Gemini Vision Plugin includes a video understanding operator with multiple modes:
#
# 1. **Describe**: Get a detailed description of the video content
# 2. **Segment**: Identify temporal segments with different characteristics
# 3. **Extract**: Extract specific information (objects, actions, events)
# 4. **Question**: Ask specific questions about the video content
#
# To use video understanding:
#
# 1. Select a video sample in the FiftyOne App
# 2. Open the operator browser
# 3. Search for "analyze_video" or "Video Understanding"
# 4. Select the mode and enter your query
#
# **Example video queries:**

# %%
# Example queries for video analysis
video_queries = [
    {
        "mode": "describe",
        "query": "Provide a detailed description of this driving video including weather, traffic conditions, and notable events"
    },
    {
        "mode": "extract",
        "query": "List all vehicle types that appear in this video with their approximate timestamps"
    },
    {
        "mode": "question",
        "query": "Are there any potentially dangerous situations in this driving video?"
    },
    {
        "mode": "segment",
        "query": "Segment this video by traffic density (low, medium, high)"
    }
]

print("Video Understanding Queries:")
for i, q in enumerate(video_queries, 1):
    print(f"\n{i}. Mode: {q['mode']}")
    print(f"   Query: {q['query']}")
# Out:
# Video Understanding Queries:
#
# 1. Mode: describe
#    Query: Provide a detailed description of this driving video including weather, traffic conditions, and notable events
#
# 2. Mode: extract
#    Query: List all vehicle types that appear in this video with their approximate timestamps
#
# 3. Mode: question
#    Query: Are there any potentially dangerous situations in this driving video?
#
# 4. Mode: segment
#    Query: Segment this video by traffic density (low, medium, high)

# %% [markdown]
# ![video_understanding](https://cdn.voxel51.com/tutorial_gemini_vision/video_understanding.webp)
#
# Now it’s your turn, keep exploring Gemini Vision to pull more insights from the video. You can try things like analyzing temporal patterns, extracting temporal annotations, and more.

# %% [markdown]
# ### Analyzing Temporal Patterns

# %% [markdown]
# Video understanding allows you to identify temporal patterns that aren't visible in individual frames:

# %%
print("Temporal Analysis Use Cases:")
print("\n1. Lane Changes:")
print("   Query: 'Identify all lane change maneuvers and their timestamps'")
print("\n2. Traffic Signal Compliance:")
print("   Query: 'Does the vehicle stop at all red lights? Provide timestamps.'")
print("\n3. Pedestrian Interactions:")
print("   Query: 'Identify all moments when pedestrians cross the road'")
print("\n4. Weather Changes:")
print("   Query: 'Does the weather change during this video? If so, when?'")
print("\n5. Scene Transitions:")
print("   Query: 'Segment this video by scene type (highway, urban, residential)'")
# Out:
# Temporal Analysis Use Cases:
#
# 1. Lane Changes:
#    Query: 'Identify all lane change maneuvers and their timestamps'
#
# 2. Traffic Signal Compliance:
#    Query: 'Does the vehicle stop at all red lights? Provide timestamps.'
#
# 3. Pedestrian Interactions:
#    Query: 'Identify all moments when pedestrians cross the road'
#
# 4. Weather Changes:
#    Query: 'Does the weather change during this video? If so, when?'
#
# 5. Scene Transitions:
#    Query: 'Segment this video by scene type (highway, urban, residential)'

# %% [markdown]
# ### Extracting Temporal Annotations

# %% [markdown]
# The responses from video understanding can be used to create temporal annotations in FiftyOne:

# %%
# Example: After using Gemini to segment a video, you can create frame-level tags
# This is a conceptual example - actual implementation would parse Gemini's response

print("Workflow for creating temporal annotations from Gemini responses:")
print("\n1. Use Video Understanding operator to segment video")
print("2. Gemini returns timestamps for each segment")
print("3. Convert timestamps to frame numbers")
print("4. Tag frames with segment characteristics")
print("\nExample: Tag frames as 'high_traffic', 'medium_traffic', 'low_traffic'")
print("based on Gemini's temporal segmentation")
# Out:
# Workflow for creating temporal annotations from Gemini responses:
#
# 1. Use Video Understanding operator to segment video
# 2. Gemini returns timestamps for each segment
# 3. Convert timestamps to frame numbers
# 4. Tag frames with segment characteristics
#
# Example: Tag frames as 'high_traffic', 'medium_traffic', 'low_traffic'
# based on Gemini's temporal segmentation

# %% [markdown]
# ## Pipeline: Scale Image Editing with Gemini
# Scale your dataset by applying multiple edit prompts to images programmatically.
# The pipeline uses the `image_editing` operator and stores metadata (`generation_type`, `prompt`)
# on each generated sample for easy filtering and visualization.

# %%
# Edit prompts to apply
prompts = ["Add rain", "Make it night time", "Add fog"]

# Select samples (exclude already-generated ones)
original_samples = dataset.match(~F("generation_type").exists())

# Number of examples to process
num_examples = 3

# Run pipeline
async def run_pipeline():
    for sample in original_samples.limit(num_examples):
        for prompt in prompts:
            print(f"Processing: {sample.filename} - '{prompt}'...")

            try:
                result = await foo.execute_operator(
                    "@adonaivera/gemini_vision/image_editing",
                    ctx={
                        "dataset": dataset,
                        "selected": [sample.id],
                    },
                    params={
                        "prompt": prompt,
                        "model": "gemini-3-pro-image-preview",
                        "use_original_size": True,
                    },
                )
                print(f"  ✓ Done: {prompt} in {sample.filename}")
            except Exception as e:
                print(f"  ✗ Error processing {prompt} in {sample.filename}: {e}")

# Run the async pipeline
await run_pipeline()

# %%
# View results - filter by generation_type field added by operator
session = fo.launch_app(dataset, auto=False)
session.view = dataset.match(F("generation_type") == "image_editing")

# %% [markdown]
# ![pipeline](https://cdn.voxel51.com/tutorial_gemini_vision/pipeline.webp)

# %% [markdown]
# You've successfully scaled your dataset using Gemini's image editing capabilities.
# Each generated image is stored with metadata (`generation_type`, `prompt`, `source_file`)
# for easy filtering and traceability.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this tutorial, we've demonstrated how the Gemini Vision Plugin extends FiftyOne's capabilities with powerful multimodal AI features:
#
# **Dataset Analysis:**
# * Used FiftyOne Brain to identify class imbalances, duplicates, and coverage gaps
# * Leveraged Gemini Vision to audit annotations and identify missing labels
# * Classified images by scenario characteristics (weather, time, scene type)
#
# **Dataset Enhancement:**
# * Generated synthetic images for underrepresented classes and scenarios
# * Edited existing images to create weather and lighting variations
# * Transferred styles between images to augment dataset diversity
#
# **Video Understanding:**
# * Analyzed temporal patterns in driving videos
# * Extracted event timestamps and segmented videos by characteristics
# * Queried video content with natural language
#
# By combining FiftyOne's data-centric workflows with Gemini Vision's multimodal AI capabilities, you can build higher-quality, more diverse datasets that lead to more robust computer vision models.
#
# For more information:
# * [Gemini Vision Plugin Documentation](https://docs.voxel51.com/plugins/plugins_ecosystem/gemini_vision_plugin.html)
# * [FiftyOne Brain Documentation](https://docs.voxel51.com/user_guide/brain.html)
# * [Google Gemini API Documentation](https://ai.google.dev/gemini-api/docs)
